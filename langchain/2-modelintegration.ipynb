# %% [markdown]
# ### Models Integration with OpenAI, GORQ and Google Gemini

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-5.4-nano")
response = model.invoke("Hello, How are you?")
print(response.content)
# Out:
# Hello! I’m doing well—thanks for asking 😊 How are you doing today?

# %% [markdown]
# ### Google Gemini Model Integration

# %%
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("why do parrots talk?")
print(response.content)
# Out:
# Parrots talk primarily because they are highly intelligent and social birds with a remarkable ability for vocal mimicry. Here's a breakdown of the key reasons:
#
# **1. Social Bonding and Communication:**
#
# * **Flock Animals:** Parrots are naturally social creatures that live in flocks in the wild. In their natural environment, they use a complex array of vocalizations to:
#     * **Maintain contact:** Keep track of flock members, especially when foraging or flying.
#     * **Warn of danger:** Alert each other to predators.
#     * **Establish social hierarchy:** Communicate dominance and submission.
#     * **Courtship:** Engage in vocal duets and displays.
#     * **Share information:** Communicate about food sources or other important discoveries.
# ...

# %% [markdown]
# ### ChatOpenAI

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello, How are you?")
print(response.content)
# Out:
# Hello! I'm just a virtual assistant, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %% [markdown]
# ### ChatGoogleGenerativeAI

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("What is called as the constitution of India?")
print(response.content)
# Out:
# The Constitution of India is called **The Constitution of India**.
#
# There isn't a separate, more common nickname or alternative name for it. It's officially and widely known as the Constitution of India.

# %% [markdown]
# ### GORQ Model Integration

# %%
model = init_chat_model("groq:qwen/qwen3-32b")
response = model.invoke("Who created the constitution of india and when was it written?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 5
#       1 model = init_chat_model("groq:qwen/qwen3-32b")
#       2 model = init_chat_model(
#       3     "qwen/qwen3-32b",
#       4     model_provider="groq")
# ----> 5 response = model.invoke("Who created the constitution of india and when was it written?")
#       6 print(response.content)
#
# File d:\workspace\Agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
# ...

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3-32b")
response = model.invoke("Who created the constitution of india and when was it written?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[13], line 4
#       1 from langchain_groq import ChatGroq
#       2
#       3 model = ChatGroq(model="qwen/qwen3-32b")
# ----> 4 response = model.invoke("Who created the constitution of india and when was it written?")
#       5 print(response.content)
#
# File d:\workspace\Agentic-AI\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
# ...

# %% [markdown]
# ### Streaming and Batch

# %% [markdown]
# #### Streaming

# %%
model = ChatOpenAI(model="gpt-4.1")
model.invoke("Write a 200 word essay on the constitution of India.")
# Out:
# AIMessage(content='The Constitution of India, adopted on January 26, 1950, is the supreme law of the country and provides the fundamental legal framework for governance. It is the longest written constitution in the world, reflecting India’s diversity, history, and aspirations. Drafted by the Constituent Assembly under the guidance of Dr. B.R. Ambedkar and others, the constitution incorporates principles of justice, liberty, equality, and fraternity.\n\nThe Constitution sets up India as a sovereign, socialist, secular, and democratic republic. It establishes a parliamentary system of government with a clear division of powers between the central and state governments, following a federal system with unitary features. The Constitution guarantees fundamental rights such as freedom of speech, equality before law, and religious freedom, ensuring protection against discrimination and safeguarding the dignity of every citizen.\n\nDirective Principles of State Policy and Fundamental Duties 
# ...

# %%
for chunk in model.stream("Write a 200 word essay on the constitution of India."):
    print(chunk.text, end="", flush=True)
# Out:
# The Constitution of India is the supreme law of the country and serves as the foundation of its democratic governance. Adopted on January 26, 1950, the Constitution was drafted by the Constituent Assembly, under the leadership of Dr. B. R. Ambedkar. It is the longest written constitution in the world, containing 395 articles and 12 schedules at the time of its adoption, which have since expanded through amendments.
#
# The Indian Constitution establishes India as a sovereign, socialist, secular, and democratic republic. It provides for a parliamentary system of government, dividing powers between the central government and the states through federalism. The document guarantees fundamental rights such as equality, freedom of speech, religion, and protection against discrimination, ensuring justice and liberty for all citizens.
#
# ...

# %% [markdown]
# #### Batch

# %%
response = model.batch([
    "Who created the constitution of india and when was it written?",
    "When did indias first prime minister take office?",
    "Who was Tamilnadu's first chief minister?"
    ],
    config={"max_concurrency": 3})

for response in response:
    print(response)
# Out:
# content='The **Constitution of India** was drafted by the **Constituent Assembly of India**. The chairman of the Drafting Committee was **Dr. B. R. Ambedkar**, who played a pivotal role in its creation.\n\n- **Writing Period:** The process of drafting the constitution began on **9 December 1946**, when the Constituent Assembly first met.\n- The final draft was completed and adopted on **26 November 1949**.\n- The Constitution came into effect on **26 January 1950**.\n\nSo, the Constitution of India was created by the Constituent Assembly, primarily drafted by Dr. B. R. Ambedkar and his committee, and was written between 1946 and 1949.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 19, 'total_tokens': 169, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_pr
# ...
